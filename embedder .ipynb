# %%
from pathlib import Path
from typing import Optional, Iterator

from docling.datamodel.accelerator_options import AcceleratorOptions, AcceleratorDevice
from docling_core.transforms.chunker import BaseChunker, PageChunker
from docling_core.types import DoclingDocument
from langchain_docling.loader import BaseMetaExtractor, MetaExtractor
from langchain_core.documents import Document

from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions, TesseractCliOcrOptions

DEFAULT_EXTENSIONS = ["."+ fmt.value for fmt in InputFormat]


def collect_documents_paths(
        directory_path: Optional[str] = None,
        recursive: bool = True,
        file_extensions: Optional[list[str]] = None
) -> list[Path]:
    if file_extensions is None:
        file_extensions = DEFAULT_EXTENSIONS

    if not directory_path:
        raise ValueError("Either file_path, directory_path, or config.FILE_PATH must be provided")

    dir_path = Path(directory_path)
    if not dir_path.exists() or not dir_path.is_dir():
        raise ValueError(f"Invalid directory path: {directory_path}")

    return _collect_files(dir_path, file_extensions, recursive)


def chunk(document_list: Iterator[DoclingDocument],
          chunker: Optional[BaseChunker] = PageChunker,
          meta_extractor: Optional[BaseMetaExtractor] = MetaExtractor()) \
        -> Iterator[Document]:
    for doc in document_list:
        chunk_iter = chunker.chunk(doc)
        for _chunk in chunk_iter:
            yield Document(
                page_content=chunker.contextualize(chunk=_chunk),
                metadata=meta_extractor.extract_chunk_meta(
                    file_path=doc.name,  # todo change this later
                    chunk=_chunk,
                ),
            )

def convert_to_markdown(documents: list[Path]) -> Iterator[DoclingDocument]:
    if not documents:
        raise ValueError("Documents list cannot be empty")

    # Create document converter with format-specific options
    converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(pipeline_options=_get_pdf_pipline())
        }
    )

    for doc in documents:
        try:
            result = converter.convert(doc)

            if not result.errors:
                yield result.document

        except Exception:
            continue


def _get_pdf_pipline() -> PdfPipelineOptions:
    pipeline_options = PdfPipelineOptions()
    pipeline_options.do_ocr = True
    pipeline_options.do_table_structure = True
    pipeline_options.table_structure_options.do_cell_matching = True
    pipeline_options.generate_picture_images = True
    pipeline_options.generate_table_images = True
    pipeline_options.ocr_options = TesseractCliOcrOptions()

    pipeline_options.accelerator_options = AcceleratorOptions(
        num_threads=4, device=AcceleratorDevice.AUTO
    )
    return pipeline_options


def _collect_files(directory: Path, extensions: list[str], recursive: bool) -> list[Path]:
    files = []
    pattern_func = directory.rglob if recursive else directory.glob
    for ext in extensions:
        files.extend(pattern_func(f"*{ext}"))
    return files

# %%
from typing import Optional
from langchain_core.documents import Document
from langchain_core.vectorstores import VectorStoreRetriever
from langchain_milvus import Milvus

from langchain_core.embeddings import Embeddings


class VectorStore:

    def __init__(
            self,
            embedding: Embeddings,
            collection_name: str = "docling_demo",
            drop_old: bool = False,
    ) -> None:

        # consistency_level = "Session"
        # auto_id = True

        self.embedding = embedding
        self.collection_name: str = collection_name
        self.vectorstore: Optional[Milvus] = None
        # self.vectorstore = Milvus(
        #     embedding_function=embedding,
        #     collection_name=self.collection_name,
        #     connection_args={
        #         "host": config.VECTOR_HOST,
        #         "port": config.VECTOR_PORT,
        #     },
        #     index_params={"index_type": "FLAT"},
        #     drop_old=drop_old,
        #     consistency_level=consistency_level,
        #     auto_id=auto_id,
        # )

    def create_from_documents(
        self,
        documents: list[Document],
        drop_old: bool = True
    ) -> Milvus:
        if not documents:
            raise ValueError("Documents list cannot be empty")

        self.vectorstore = Milvus.from_documents(
            documents=documents,
            embedding=self.embedding,
            collection_name=self.collection_name,
            connection_args={"host": "localhost", "port": "19530"},
            index_params={
                "index_type": "FLAT",
                "metric_type": "IP"  # use "L2" for Euclidean
            },
            drop_old=drop_old,
        )
        return self.vectorstore


    def add_documents(self, documents: list[Document]) -> list[str]:
        if not self.vectorstore:
            raise RuntimeError(
                "Vector store not initialized. Call create_from_documents() first."
            )

        if not documents:
            raise ValueError("Documents list cannot be empty")

        return self.vectorstore.add_documents(documents)

    def get_retriever(self, top_k: int = 5) -> VectorStoreRetriever:
        if not self.vectorstore:
            raise RuntimeError(
                "Vector store not initialized. Call create_from_documents() first."
            )

        return self.vectorstore.as_retriever(search_kwargs={"k": top_k})

    def similarity_search(
            self,
            query: str,
            k: int = 5
    ) -> list[Document]:
        if not self.vectorstore:
            raise RuntimeError(
                "Vector store not initialized. Call create_from_documents() first."
            )

        return self.vectorstore.similarity_search(query, k=k)

# %%
# from typing import Optional, List
# import faiss
# import numpy as np
# from langchain.docstore.document import Document
# from langchain_community.vectorstores import FAISS
# from langchain.embeddings.base import Embeddings
# from langchain.vectorstores.base import VectorStoreRetriever
#
#
# class VectorStore:
#     def __init__(
#         self,
#         embedding: Embeddings,
#         collection_name: str = "faiss_demo",
#         drop_old: bool = False,
#     ) -> None:
#         self.embedding = embedding
#         self.collection_name = collection_name
#         self.vectorstore: Optional[FAISS] = None
#         self.drop_old = drop_old
#
#         if drop_old:
#             # Start fresh
#             self.vectorstore = None
#
#     def create_from_documents(self, documents: List[Document]) -> FAISS:
#         """
#         Create a FAISS index from a list of documents.
#         """
#         if not documents:
#             raise ValueError("Documents list cannot be empty")
#
#         # Build FAISS index
#         self.vectorstore = FAISS.from_documents(
#             documents=documents,
#             embedding=self.embedding
#         )
#
#         return self.vectorstore
#
#     def add_documents(self, documents: List[Document]) -> List[str]:
#         """
#         Add new documents to an existing FAISS index.
#         """
#         if not self.vectorstore:
#             raise RuntimeError(
#                 "Vector store not initialized. Call create_from_documents() first."
#             )
#
#         if not documents:
#             raise ValueError("Documents list cannot be empty")
#
#         return self.vectorstore.add_documents(documents)
#
#     def get_retriever(self, top_k: int = 5) -> VectorStoreRetriever:
#         """
#         Return a retriever object for semantic search.
#         """
#         if not self.vectorstore:
#             raise RuntimeError(
#                 "Vector store not initialized. Call create_from_documents() first."
#             )
#
#         return self.vectorstore.as_retriever(search_kwargs={"k": top_k})
#
#     def similarity_search(self, query: str, k: int = 5) -> List[Document]:
#         """
#         Perform similarity search on the FAISS index.
#         """
#         if not self.vectorstore:
#             raise RuntimeError(
#                 "Vector store not initialized. Call create_from_documents() first."
#             )
#
#         return self.vectorstore.similarity_search(query, k=k)
#
#     def save_local(self, path: str) -> None:
#         """
#         Save FAISS index to disk.
#         """
#         if not self.vectorstore:
#             raise RuntimeError("No FAISS index to save.")
#
#         self.vectorstore.save_local(path)
#
#     def load_local(self, path: str) -> None:
#         """
#         Load FAISS index from disk.
#         """
#         self.vectorstore = FAISS.load_local(
#             path=path,
#             embeddings=self.embedding,
#             allow_dangerous_deserialization=True,
#         )
#
# Out:
# 2025-10-16 03:57:54,531 - INFO - Loading faiss with AVX2 support.
# 2025-10-16 03:57:54,606 - INFO - Successfully loaded faiss with AVX2 support.

# %%
from typing import Optional
from langchain_huggingface.embeddings import HuggingFaceEmbeddings


class EmbeddingModel:

    def __init__(self, model_id: Optional[str] = None) -> None:
        self.model_id: str = "sentence-transformers/all-MiniLM-L6-v2"
        self.embedding: HuggingFaceEmbeddings = HuggingFaceEmbeddings(
            model_name=self.model_id
        )

    def get_embedding(self) -> HuggingFaceEmbeddings:
        return self.embedding

# %%
from typing import Optional, Iterator

from colorama import Fore, Style, init
from docling_core.transforms.chunker.hybrid_chunker import HybridChunker
from langchain_huggingface import HuggingFaceEmbeddings

# Initialize colorama
init(autoreset=True)


def _print_step(emoji: str, message: str, color: str = Fore.CYAN):
    """Print a colored step message."""
    print(f"{color}{emoji} {message}{Style.RESET_ALL}")


def _print_success(emoji: str, message: str):
    """Print a success message."""
    print(f"{Fore.GREEN}{emoji} {message}{Style.RESET_ALL}")


def _print_info(emoji: str, message: str):
    """Print an info message."""
    print(f"{Fore.YELLOW}{emoji} {message}{Style.RESET_ALL}")


def ingest_pipeline(
        directory_path: Optional[str] = None,
        recursive: bool = True,
        file_extensions: Optional[list[str]] = None,
        batch_size: int = 100
) -> VectorStore:
    """
    Complete ingestion pipeline: collect, convert, chunk, embed, and store documents.

    Args:
        directory_path: Path to directory containing documents
        recursive: Whether to search subdirectories
        file_extensions: List of file extensions to process
        batch_size: Number of chunks to collect before adding to vector store

    Returns:
        VectorStore instance with embedded documents
    """
    print(f"\n{Fore.MAGENTA}{'='*70}{Style.RESET_ALL}")
    _print_step("🚀", "Starting Document Ingestion Pipeline", Fore.MAGENTA)
    print(f"{Fore.MAGENTA}{'='*70}{Style.RESET_ALL}\n")

    # Step 1: Collect document paths
    _print_step("📁", f"Collecting documents from: {directory_path}", Fore.CYAN)
    _print_info("  ℹ️", f"Recursive search: {recursive}")
    if file_extensions:
        _print_info("  ℹ️", f"File extensions: {', '.join(file_extensions)}")

    paths = collect_documents_paths(directory_path, recursive, file_extensions)
    _print_success("  ✅", f"Found {len(paths)} document(s)")

    # Step 2: Convert documents to markdown
    _print_step("📄", "Converting documents to markdown format...", Fore.CYAN)
    iter_document = convert_to_markdown(paths)

    # Step 3: Chunking
    _print_step("✂️", "Chunking documents with HybridChunker...", Fore.CYAN)
    _print_info("  ℹ️", f"Batch size: {batch_size} chunks")
    chunker = HybridChunker()
    chunk_iter = chunk(iter_document, chunker)

    # Step 4: Initialize embeddings and vector store
    _print_step("🧠", "Initializing embedding model...", Fore.CYAN)
    model_name = "all-MiniLM-L6-v2"
    device = "cpu"

    embedding = HuggingFaceEmbeddings(
        model_name=model_name,
        model_kwargs={'device': device},
        encode_kwargs={'normalize_embeddings': True}
    )

    _print_success("  ✅", "Embedding model loaded")

    _print_step("🗄️", "Creating vector store...", Fore.CYAN)
    vector_store = VectorStore(embedding)
    _print_success("  ✅", "Vector store initialized")

    # Step 5: Add chunks to vector store in batches
    _print_step("💾", "Adding chunks to vector store in batches...", Fore.CYAN)

    batch = []
    total_chunks = 0
    batch_count = 0

    for doc in chunk_iter:
        if total_chunks == 0:
            temp = [doc]
            vector_store.create_from_documents(temp)
        batch.append(doc)
        total_chunks += 1

        if len(batch) >= batch_size:
            batch_count += 1
            _print_info("  📦", f"Processing batch {batch_count} ({len(batch)} chunks)...")
            vector_store.add_documents(batch)
            _print_success("  ✅", f"Batch {batch_count} added successfully")
            batch = []

    # Add any remaining chunks
    if batch:
        batch_count += 1
        _print_info("  📦", f"Processing final batch ({len(batch)} chunks)...")
        vector_store.add_documents(batch)
        _print_success("  ✅", f"Final batch added successfully")

    # Summary
    print(f"\n{Fore.GREEN}{'='*70}{Style.RESET_ALL}")
    _print_success("🎉", "Ingestion Pipeline Completed Successfully!")
    print(f"{Fore.GREEN}{'='*70}{Style.RESET_ALL}")
    _print_info("📊", f"Total documents processed: {len(paths)}")
    _print_info("📊", f"Total chunks created: {total_chunks}")
    _print_info("📊", f"Total batches processed: {batch_count}")
    print()

    return vector_store

# %%
directory = "test"

# %%
store = ingest_pipeline(directory)
# Out:
# ======================================================================
# 🚀 Starting Document Ingestion Pipeline
# ======================================================================
#
# 📁 Collecting documents from: test
#   ℹ️ Recursive search: True
#   ✅ Found 804 document(s)
# 📄 Converting documents to markdown format...
# ✂️ Chunking documents with HybridChunker...
#   ℹ️ Batch size: 100 chunks
# 🧠 Initializing embedding model...
# 2025-10-16 04:48:56,620 - INFO - Load pretrained SentenceTransformer: all-MiniLM-L6-v2
#   ✅ Embedding model loaded
# 🗄️ Creating vector store...
#   ✅ Vector store initialized
# 💾 Adding chunks to vector store in batches...
# 2025-10-16 04:48:59,520 - INFO - detected formats: [<InputFormat.DOCX: 'docx'>]
# 2025-10-16 04:48:59,535 - INFO - Going to convert document batch...
# 2025-10-16 04:48:59,536 - INFO - Initializing pipeline for SimplePipeline with options hash 995a146ad601044538e6a923bea22f4e
# 2025-10-16 04:48:59,537 - INFO - Processing document Content_Assets_20240722IRF.docx
# 2025-10-16 04:48:59,549 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:48:59,556 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:48:59,561 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:48:59,577 - INFO - deleted item in tree at stack: (6,) => #/texts/9
# 2025-10-16 04:48:59,585 - INFO - deleted item in tree at stack: (8,) => #/texts/13
# 2025-10-16 04:48:59,607 - INFO - deleted item in tree at stack: (10,) => #/texts/28
# 2025-10-16 04:48:59,610 - INFO - deleted item in tree at stack: (10,) => #/texts/28
# 2025-10-16 04:48:59,620 - INFO - deleted item in tree at stack: (10,) => #/texts/35
# 2025-10-16 04:48:59,631 - INFO - deleted item in tree at stack: (10,) => #/texts/42
# 2025-10-16 04:48:59,633 - INFO - deleted item in tree at stack: (10,) => #/texts/42
# 2025-10-16 04:48:59,643 - INFO - deleted item in tree at stack: (10,) => #/texts/47
# 2025-10-16 04:48:59,646 - INFO - Finished converting document Content_Assets_20240722IRF.docx in 0.13 sec.
# 2025-10-16 04:49:00,947 - INFO - detected formats: [<InputFormat.DOCX: 'docx'>]
# 2025-10-16 04:49:00,968 - INFO - Going to convert document batch...
# 2025-10-16 04:49:00,969 - INFO - Processing document Content_Assets_20240722LAIR.docx
# 2025-10-16 04:49:00,976 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:00,981 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:00,985 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:00,988 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:00,991 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:00,994 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:00,997 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:01,000 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:01,002 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:01,005 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:01,006 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:01,010 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:01,014 - INFO - deleted item in tree at stack: (1,) => #/texts/0
# 2025-10-16 04:49:01,020 - INFO - deleted item in tree at stack: (3,) => #/texts/1
# 2025-10-16 04:49:01,043 - INFO - deleted item in tree at stack: (12,) => #/texts/25
# 2025-10-16 04:49:01,046 - INFO - deleted item in tree at stack: (12,) => #/texts/25
# 2025-10-16 04:49:01,054 - INFO - deleted item in tree at stack: (12,) => #/texts/30
# 2025-10-16 04:49:01,065 - INFO - deleted item in tree at stack: (12,) => #/texts/36
# 2025-10-16 04:49:01,070 - INFO - deleted item in tree at stack: (12,) => #/texts/36
# 2025-10-16 04:49:01,081 - INFO - deleted item in tree at stack: (12,) => #/texts/41
# 2025-10-16 04:49:01,084 - INFO - Finished converting document Content_Assets_20240722LAIR.docx in 0.14 sec.
# 2025-10-16 04:49:01,129 - INFO - detected formats: [<InputFormat.DOCX: 'docx'>]
# 2025-10-16 04:49:01,133 - INFO - Going to convert document batch...
# 2025-10-16 04:49:01,134 - INFO - Processing document Content_Assets_20220125ApplicationForm.docx
# 2025-10-16 04:49:01,146 - INFO - deleted item in tree at stack: (4,) => #/texts/2
# 2025-10-16 04:49:01,150 - INFO - deleted item in tree at stack: (5,) => #/texts/4
# 2025-10-16 04:49:01,152 - INFO - deleted item in tree at stack: (5,) => #/texts/4
# 2025-10-16 04:49:01,154 - INFO - deleted item in tree at stack: (5,) => #/texts/4
# 2025-10-16 04:49:01,156 - INFO - deleted item in tree at stack: (5,) => #/texts/4
# 2025-10-16 04:49:01,159 - INFO - deleted item in tree at stack: (5,) => #/texts/6
# 2025-10-16 04:49:01,160 - INFO - deleted item in tree at stack: (5,) => #/texts/6
# 2025-10-16 04:49:01,164 - INFO - deleted item in tree at stack: (5,) => #/texts/8
# 2025-10-16 04:49:01,176 - INFO - deleted item in tree at stack: (8,) => #/texts/23
# 2025-10-16 04:49:01,189 - INFO - deleted item in tree at stack: (9,) => #/texts/37
# 2025-10-16 04:49:01,195 - INFO - deleted item in tree at stack: (9,) => #/texts/41
# 2025-10-16 04:49:01,201 - INFO - deleted item in tree at stack: (9,) => #/texts/44
# 2025-10-16 04:49:01,206 - INFO - deleted item in tree at stack: (9,) => #/texts/47
# 2025-10-16 04:49:01,209 - INFO - deleted item in tree at stack: (9,) => #/texts/47
# 2025-10-16 04:49:01,211 - INFO - deleted item in tree at stack: (9,) => #/texts/47
# 2025-10-16 04:49:01,215 - INFO - deleted item in tree at stack: (9,) => #/texts/47
# 2025-10-16 04:49:01,218 - INFO - deleted item in tree at stack: (9,) => #/texts/47
# 2025-10-16 04:49:01,221 - INFO - deleted item in tree at stack: (9,) => #/texts/47
# 2025-10-16 04:49:01,223 - INFO - deleted item in tree at stack: (9,) => #/texts/47
# 2025-10-16 04:49:01,231 - INFO - deleted item in tree at stack: (10,) => #/texts/54
# 2025-10-16 04:49:01,235 - INFO - deleted item in tree at stack: (10,) => #/texts/56
# 2025-10-16 04:49:01,243 - INFO - Finished converting document Content_Assets_20220125ApplicationForm.docx in 0.11 sec.
# Token indices sequence length is longer than the specified maximum sequence length for this model (3249 > 512). Running this sequence through the model will result in indexing errors
# 2025-10-16 04:49:01,394 - INFO - detected formats: [<InputFormat.DOCX: 'docx'>]
# 2025-10-16 04:49:01,399 - INFO - Going to convert document batch...
# 2025-10-16 04:49:01,400 - INFO - Processing document Content_Assets_20250212FormulaireCandidatureSafar2025.docx
# 2025-10-16 04:49:01,511 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,513 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,517 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,521 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,526 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,530 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,533 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,535 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,538 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,540 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,543 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,545 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,548 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,552 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,555 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,558 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,564 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,569 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,574 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,579 - INFO - deleted item in tree at stack: (1, 1, 8, 0, 0, 0, 0, 15) => #/texts/29
# 2025-10-16 04:49:01,624 - INFO - Finished converting document Content_Assets_20250212FormulaireCandidatureSafar2025.docx in 0.24 sec.
# 2025-10-16 04:49:01,653 - INFO - detected formats: [<InputFormat.DOCX: 'docx'>]
# 2025-10-16 04:49:01,657 - INFO - Going to convert document batch...
# 2025-10-16 04:49:01,657 - INFO - Processing document Content_Assets_20220517Individual PhDThesis Proposal-102750.docx
# 2025-10-16 04:49:01,663 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,666 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,668 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,670 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,672 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,674 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,675 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,677 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,678 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,679 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,681 - INFO - deleted item in tree at stack: (3,) => #/texts/2
# 2025-10-16 04:49:01,684 - INFO - deleted item in tree at stack: (3,) => #/texts/4
# 2025-10-16 04:49:01,686 - INFO - deleted item in tree at stack: (3,) => #/texts/4
# 2025-10-16 04:49:01,687 - INFO - deleted item in tree at stack: (3,) => #/texts/4
# 2025-10-16 04:49:01,688 - INFO - deleted item in tree at stack: (3,) => #/texts/4
# 2025-10-16 04:49:01,689 - INFO - deleted item in tree at stack: (3,) => #/texts/4
# 2025-10-16 04:49:01,691 - INFO - deleted item in tree at stack: (3,) => #/texts/4
# 2025-10-16 04:49:01,692 - INFO - deleted item in tree at stack: (3,) => #/texts/4
# 2025-10-16 04:49:01,693 - INFO - deleted item in tree at stack: (3,) => #/texts/4
# 2025-10-16 04:49:01,695 - INFO - deleted item in tree at stack: (3,) => #/texts/4
# 2025-10-16 04:49:01,699 - INFO - deleted item in tree at stack: (3,) => #/texts/6
# 2025-10-16 04:49:01,700 - INFO - deleted item in tree at stack: (3,) => #/texts/6
# 2025-10-16 04:49:01,703 - INFO - deleted item in tree at stack: (3,) => #/texts/8
# 2025-10-16 04:49:01,705 - INFO - deleted item in tree at stack: (3,) => #/texts/8
# 2025-10-16 04:49:01,706 - INFO - deleted item in tree at stack: (3,) => #/texts/8
# 2025-10-16 04:49:01,708 - INFO - deleted item in tree at stack: (3,) => #/texts/8
# 2025-10-16 04:49:01,709 - INFO - deleted item in tree at stack: (3,) => #/texts/8
# 2025-10-16 04:49:01,711 - INFO - deleted item in tree at stack: (3,) => #/texts/8
# 2025-10-16 04:49:01,713 - INFO - deleted item in tree at stack: (3,) => #/texts/8
# 2025-10-16 04:49:01,714 - INFO - deleted item in tree at stack: (3,) => #/texts/8
# 2025-10-16 04:49:01,717 - INFO - deleted item in tree at stack: (5,) => #/texts/9
# 2025-10-16 04:49:01,723 - INFO - deleted item in tree at stack: (7,) => #/texts/13
# 2025-10-16 04:49:01,725 - INFO - deleted item in tree at stack: (7,) => #/texts/13
# 2025-10-16 04:49:01,729 - INFO - deleted item in tree at stack: (9,) => #/texts/14
# 2025-10-16 04:49:01,732 - INFO - deleted item in tree at stack: (9,) => #/texts/14
# 2025-10-16 04:49:01,735 - INFO - deleted item in tree at stack: (9,) => #/texts/14
# 2025-10-16 04:49:01,737 - INFO - deleted item in tree at stack: (9,) => #/texts/14
# 2025-10-16 04:49:01,740 - INFO - deleted item in tree at stack: (9,) => #/texts/14
# 2025-10-16 04:49:01,744 - INFO - deleted item in tree at stack: (9,) => #/texts/14
# 2025-10-16 04:49:01,746 - INFO - deleted item in tree at stack: (9,) => #/texts/14
# 2025-10-16 04:49:01,750 - INFO - deleted item in tree at stack: (11,) => #/texts/15
# 2025-10-16 04:49:01,752 - INFO - deleted item in tree at stack: (11,) => #/texts/15
# 2025-10-16 04:49:01,754 - INFO - deleted item in tree at stack: (11,) => #/texts/15
# 2025-10-16 04:49:01,756 - INFO - deleted item in tree at stack: (11,) => #/texts/15
# 2025-10-16 04:49:01,759 - INFO - deleted item in tree at stack: (11,) => #/texts/15
# 2025-10-16 04:49:01,762 - INFO - deleted item in tree at stack: (11,) => #/texts/15
# 2025-10-16 04:49:01,764 - INFO - deleted item in tree at stack: (11,) => #/texts/15
# 2025-10-16 04:49:01,769 - INFO - Finished converting document Content_Assets_20220517Individual PhDThesis Proposal-102750.docx in 0.12 sec.
# 2025-10-16 04:49:01,817 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:01,826 - INFO - Going to convert document batch...
# 2025-10-16 04:49:01,827 - INFO - Processing document ruc.html
# 2025-10-16 04:49:01,844 - INFO - Finished converting document ruc.html in 0.03 sec.
# 2025-10-16 04:49:01,975 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:01,997 - INFO - Going to convert document batch...
# 2025-10-16 04:49:01,998 - INFO - Processing document tto.html
# 2025-10-16 04:49:02,038 - INFO - Finished converting document tto.html in 0.09 sec.
# 2025-10-16 04:49:02,135 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:02,143 - INFO - Going to convert document batch...
# 2025-10-16 04:49:02,144 - INFO - Processing document uclc.html
# 2025-10-16 04:49:02,159 - INFO - Finished converting document uclc.html in 0.02 sec.
# 2025-10-16 04:49:02,256 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:02,265 - INFO - Going to convert document batch...
# 2025-10-16 04:49:02,266 - INFO - Processing document rcmme.html
# 2025-10-16 04:49:02,277 - INFO - Finished converting document rcmme.html in 0.04 sec.
# 2025-10-16 04:49:02,315 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:02,329 - INFO - Going to convert document batch...
# 2025-10-16 04:49:02,330 - INFO - Processing document alumni.html
# 2025-10-16 04:49:02,348 - INFO - Finished converting document alumni.html in 0.03 sec.
# 2025-10-16 04:49:02,402 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:02,421 - INFO - Going to convert document batch...
# 2025-10-16 04:49:02,422 - INFO - Processing document en_home.html
# 2025-10-16 04:49:02,446 - INFO - deleted item in tree at stack: (15, 0, 15) => #/texts/173
# 2025-10-16 04:49:02,449 - INFO - deleted item in tree at stack: (15, 0, 15) => #/texts/173
# 2025-10-16 04:49:02,453 - INFO - deleted item in tree at stack: (15, 0, 15) => #/texts/173
# 2025-10-16 04:49:02,457 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/173
# 2025-10-16 04:49:02,460 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/173
# 2025-10-16 04:49:02,464 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/173
# 2025-10-16 04:49:02,467 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/173
# 2025-10-16 04:49:02,470 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/173
# 2025-10-16 04:49:02,473 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/173
# 2025-10-16 04:49:02,476 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/173
# 2025-10-16 04:49:02,479 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/173
# 2025-10-16 04:49:02,482 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/173
# 2025-10-16 04:49:02,485 - INFO - deleted item in tree at stack: (15, 0, 15) => #/texts/173
# 2025-10-16 04:49:02,489 - INFO - deleted item in tree at stack: (15, 0, 15) => #/texts/174
# 2025-10-16 04:49:02,492 - INFO - deleted item in tree at stack: (15, 0, 15) => #/texts/175
# 2025-10-16 04:49:02,496 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,499 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,503 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,506 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,511 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,515 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,519 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,523 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,527 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,531 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,535 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/176
# 2025-10-16 04:49:02,539 - INFO - deleted item in tree at stack: (15, 0, 15) => #/texts/176
# 2025-10-16 04:49:02,543 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/177
# 2025-10-16 04:49:02,547 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/177
# 2025-10-16 04:49:02,551 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/177
# 2025-10-16 04:49:02,556 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/177
# 2025-10-16 04:49:02,560 - INFO - deleted item in tree at stack: (15, 0, 15) => #/texts/177
# 2025-10-16 04:49:02,566 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/178
# 2025-10-16 04:49:02,572 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/178
# 2025-10-16 04:49:02,577 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/178
# 2025-10-16 04:49:02,580 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/178
# 2025-10-16 04:49:02,585 - INFO - deleted item in tree at stack: (15, 0, 15) => #/texts/178
# 2025-10-16 04:49:02,589 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,593 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,597 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,602 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,610 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,619 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,625 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,629 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,634 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,638 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,642 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,649 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,658 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,666 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,675 - INFO - deleted item in tree at stack: (15, 0, 14) => #/texts/179
# 2025-10-16 04:49:02,690 - INFO - Finished converting document en_home.html in 0.29 sec.
#   📦 Processing batch 1 (100 chunks)...
#   ✅ Batch 1 added successfully
# 2025-10-16 04:49:06,886 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:06,904 - INFO - Going to convert document batch...
# 2025-10-16 04:49:06,905 - INFO - Processing document library.html
# 2025-10-16 04:49:06,928 - INFO - Finished converting document library.html in 0.04 sec.
# 2025-10-16 04:49:06,997 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:07,005 - INFO - Going to convert document batch...
# 2025-10-16 04:49:07,006 - INFO - Processing document business.html
# 2025-10-16 04:49:07,021 - INFO - Finished converting document business.html in 0.03 sec.
# 2025-10-16 04:49:07,117 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:07,132 - INFO - Going to convert document batch...
# 2025-10-16 04:49:07,133 - INFO - Processing document give-usek.html
# 2025-10-16 04:49:07,150 - INFO - Finished converting document give-usek.html in 0.04 sec.
# 2025-10-16 04:49:07,181 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:07,193 - INFO - Going to convert document batch...
# 2025-10-16 04:49:07,194 - INFO - Processing document en_research.html
# 2025-10-16 04:49:07,205 - INFO - Finished converting document en_research.html in 0.03 sec.
# 2025-10-16 04:49:07,278 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:07,287 - INFO - Going to convert document batch...
# 2025-10-16 04:49:07,287 - INFO - Processing document en_students.html
# 2025-10-16 04:49:07,300 - INFO - Finished converting document en_students.html in 0.02 sec.
# 2025-10-16 04:49:07,379 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:07,387 - INFO - Going to convert document batch...
# 2025-10-16 04:49:07,387 - INFO - Processing document fr_a-propos.html
# 2025-10-16 04:49:07,398 - INFO - Finished converting document fr_a-propos.html in 0.02 sec.
# 2025-10-16 04:49:07,481 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:07,489 - INFO - Going to convert document batch...
# 2025-10-16 04:49:07,490 - INFO - Processing document Site_SubPage.html
# 2025-10-16 04:49:07,505 - INFO - Finished converting document Site_SubPage.html in 0.02 sec.
#   📦 Processing batch 2 (100 chunks)...
#   ✅ Batch 2 added successfully
# 2025-10-16 04:49:11,378 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:11,393 - INFO - Going to convert document batch...
# 2025-10-16 04:49:11,394 - INFO - Processing document en_academics.html
# 2025-10-16 04:49:11,409 - INFO - Finished converting document en_academics.html in 0.03 sec.
# 2025-10-16 04:49:11,534 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:11,543 - INFO - Going to convert document batch...
# 2025-10-16 04:49:11,544 - INFO - Processing document fr_etudiants.html
# 2025-10-16 04:49:11,556 - INFO - Finished converting document fr_etudiants.html in 0.02 sec.
# 2025-10-16 04:49:11,632 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:11,645 - INFO - Going to convert document batch...
# 2025-10-16 04:49:11,645 - INFO - Processing document students_cao.html
# 2025-10-16 04:49:11,659 - INFO - Finished converting document students_cao.html in 0.03 sec.
# 2025-10-16 04:49:11,777 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:11,792 - INFO - Going to convert document batch...
# 2025-10-16 04:49:11,793 - INFO - Processing document students_umc.html
# 2025-10-16 04:49:11,813 - INFO - Finished converting document students_umc.html in 0.04 sec.
# 2025-10-16 04:49:11,956 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:11,966 - INFO - Going to convert document batch...
# 2025-10-16 04:49:11,966 - INFO - Processing document career-center.html
# 2025-10-16 04:49:11,984 - INFO - Finished converting document career-center.html in 0.03 sec.
#   📦 Processing batch 3 (100 chunks)...
#   ✅ Batch 3 added successfully
# 2025-10-16 04:49:16,311 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:16,321 - INFO - Going to convert document batch...
# 2025-10-16 04:49:16,322 - INFO - Processing document en_about-usek.html
# 2025-10-16 04:49:16,334 - INFO - Finished converting document en_about-usek.html in 0.02 sec.
# 2025-10-16 04:49:16,420 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:16,427 - INFO - Going to convert document batch...
# 2025-10-16 04:49:16,427 - INFO - Processing document rcmme_contact.html
# 2025-10-16 04:49:16,435 - INFO - Finished converting document rcmme_contact.html in 0.02 sec.
# 2025-10-16 04:49:16,460 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:16,471 - INFO - Going to convert document batch...
# 2025-10-16 04:49:16,472 - INFO - Processing document usekpresident.html
# 2025-10-16 04:49:16,492 - INFO - Finished converting document usekpresident.html in 0.03 sec.
# 2025-10-16 04:49:16,620 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:16,629 - INFO - Going to convert document batch...
# 2025-10-16 04:49:16,629 - INFO - Processing document academics_ltec.html
# 2025-10-16 04:49:16,642 - INFO - Finished converting document academics_ltec.html in 0.02 sec.
# 2025-10-16 04:49:16,729 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:16,738 - INFO - Going to convert document batch...
# 2025-10-16 04:49:16,739 - INFO - Processing document rcmme_archives.html
# 2025-10-16 04:49:16,753 - INFO - Finished converting document rcmme_archives.html in 0.02 sec.
# 2025-10-16 04:49:16,796 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:16,804 - INFO - Going to convert document batch...
# 2025-10-16 04:49:16,805 - INFO - Processing document rcmme_partners.html
# 2025-10-16 04:49:16,815 - INFO - Finished converting document rcmme_partners.html in 0.02 sec.
# 2025-10-16 04:49:16,848 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:16,857 - INFO - Going to convert document batch...
# 2025-10-16 04:49:16,858 - INFO - Processing document rcmme_patterns.html
# 2025-10-16 04:49:16,869 - INFO - Finished converting document rcmme_patterns.html in 0.02 sec.
# 2025-10-16 04:49:16,899 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:16,902 - INFO - Going to convert document batch...
# 2025-10-16 04:49:16,902 - INFO - Processing document site_ErrorPage.html
# 2025-10-16 04:49:16,905 - INFO - Finished converting document site_ErrorPage.html in 0.01 sec.
# 2025-10-16 04:49:16,913 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:16,921 - INFO - Going to convert document batch...
# 2025-10-16 04:49:16,922 - INFO - Processing document business_paris2.html
# 2025-10-16 04:49:16,933 - INFO - Finished converting document business_paris2.html in 0.02 sec.
# 2025-10-16 04:49:17,034 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:17,044 - INFO - Going to convert document batch...
# 2025-10-16 04:49:17,045 - INFO - Processing document fr_plan-du-site.html
# 2025-10-16 04:49:17,067 - INFO - Finished converting document fr_plan-du-site.html in 0.04 sec.
#   📦 Processing batch 4 (100 chunks)...
#   ✅ Batch 4 added successfully
# 2025-10-16 04:49:21,106 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:21,115 - INFO - Going to convert document batch...
# 2025-10-16 04:49:21,116 - INFO - Processing document doctoral-college.html
# 2025-10-16 04:49:21,127 - INFO - Finished converting document doctoral-college.html in 0.02 sec.
# 2025-10-16 04:49:21,202 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:21,207 - INFO - Going to convert document batch...
# 2025-10-16 04:49:21,208 - INFO - Processing document rcmme_activities.html
# 2025-10-16 04:49:21,214 - INFO - Finished converting document rcmme_activities.html in 0.01 sec.
# 2025-10-16 04:49:21,238 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:21,245 - INFO - Going to convert document batch...
# 2025-10-16 04:49:21,245 - INFO - Processing document rcmme_objectives.html
# 2025-10-16 04:49:21,253 - INFO - Finished converting document rcmme_objectives.html in 0.02 sec.
# 2025-10-16 04:49:21,288 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:21,297 - INFO - Going to convert document batch...
# 2025-10-16 04:49:21,297 - INFO - Processing document en_news-and-media.html
# 2025-10-16 04:49:21,310 - INFO - Finished converting document en_news-and-media.html in 0.02 sec.
# 2025-10-16 04:49:21,396 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:21,404 - INFO - Going to convert document batch...
# 2025-10-16 04:49:21,404 - INFO - Processing document en_privacy-policy.html
# 2025-10-16 04:49:21,417 - INFO - Finished converting document en_privacy-policy.html in 0.02 sec.
# 2025-10-16 04:49:21,536 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:21,543 - INFO - Going to convert document batch...
# 2025-10-16 04:49:21,543 - INFO - Processing document fr_plan-du-campus.html
# 2025-10-16 04:49:21,554 - INFO - Finished converting document fr_plan-du-campus.html in 0.02 sec.
# 2025-10-16 04:49:21,627 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:21,643 - INFO - Going to convert document batch...
# 2025-10-16 04:49:21,643 - INFO - Processing document fr_vie-academique.html
# 2025-10-16 04:49:21,659 - INFO - Finished converting document fr_vie-academique.html in 0.03 sec.
#   📦 Processing batch 5 (100 chunks)...
#   ✅ Batch 5 added successfully
# 2025-10-16 04:49:25,841 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:25,852 - INFO - Going to convert document batch...
# 2025-10-16 04:49:25,853 - INFO - Processing document law-journal_about.html
# 2025-10-16 04:49:25,866 - INFO - Finished converting document law-journal_about.html in 0.03 sec.
# 2025-10-16 04:49:25,960 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:25,972 - INFO - Going to convert document batch...
# 2025-10-16 04:49:25,973 - INFO - Processing document uclc_testimonials.html
# 2025-10-16 04:49:25,986 - INFO - Finished converting document uclc_testimonials.html in 0.03 sec.
# 2025-10-16 04:49:26,099 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:26,106 - INFO - Going to convert document batch...
# 2025-10-16 04:49:26,107 - INFO - Processing document Site_LandingGlobal.html
# 2025-10-16 04:49:26,123 - INFO - Finished converting document Site_LandingGlobal.html in 0.02 sec.
# 2025-10-16 04:49:26,194 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:26,207 - INFO - Going to convert document batch...
# 2025-10-16 04:49:26,208 - INFO - Processing document Site_ListingBlocks.html
# 2025-10-16 04:49:26,225 - INFO - Finished converting document Site_ListingBlocks.html in 0.03 sec.
# 2025-10-16 04:49:26,342 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:26,356 - INFO - Going to convert document batch...
# 2025-10-16 04:49:26,357 - INFO - Processing document ecole-d-ingenieurs.html
# 2025-10-16 04:49:26,374 - INFO - Finished converting document ecole-d-ingenieurs.html in 0.03 sec.
# 2025-10-16 04:49:26,454 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:26,464 - INFO - Going to convert document batch...
# 2025-10-16 04:49:26,465 - INFO - Processing document en_contact_schools.html
# 2025-10-16 04:49:26,482 - INFO - Finished converting document en_contact_schools.html in 0.03 sec.
# 2025-10-16 04:49:26,593 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:26,603 - INFO - Going to convert document batch...
# 2025-10-16 04:49:26,604 - INFO - Processing document fr_contact_schools.html
# 2025-10-16 04:49:26,618 - INFO - Finished converting document fr_contact_schools.html in 0.03 sec.
#   📦 Processing batch 6 (100 chunks)...
#   ✅ Batch 6 added successfully
# 2025-10-16 04:49:31,059 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:31,071 - INFO - Going to convert document batch...
# 2025-10-16 04:49:31,072 - INFO - Processing document ubs_administration.html
# 2025-10-16 04:49:31,088 - INFO - Finished converting document ubs_administration.html in 0.03 sec.
# 2025-10-16 04:49:31,198 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:31,206 - INFO - Going to convert document batch...
# 2025-10-16 04:49:31,207 - INFO - Processing document academics_uclc_news.html
# 2025-10-16 04:49:31,219 - INFO - Finished converting document academics_uclc_news.html in 0.02 sec.
# 2025-10-16 04:49:31,300 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:31,309 - INFO - Going to convert document batch...
# 2025-10-16 04:49:31,310 - INFO - Processing document fr_a-propos_emplois.html
# 2025-10-16 04:49:31,325 - INFO - Finished converting document fr_a-propos_emplois.html in 0.03 sec.
# 2025-10-16 04:49:31,403 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:31,411 - INFO - Going to convert document batch...
# 2025-10-16 04:49:31,412 - INFO - Processing document law-journal_contact.html
# 2025-10-16 04:49:31,426 - INFO - Finished converting document law-journal_contact.html in 0.02 sec.
# 2025-10-16 04:49:31,525 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:31,531 - INFO - Going to convert document batch...
# 2025-10-16 04:49:31,532 - INFO - Processing document rcmme_announcements.html
# 2025-10-16 04:49:31,539 - INFO - Finished converting document rcmme_announcements.html in 0.02 sec.
# 2025-10-16 04:49:31,562 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:31,572 - INFO - Going to convert document batch...
# 2025-10-16 04:49:31,573 - INFO - Processing document uclc_directors-word.html
# 2025-10-16 04:49:31,585 - INFO - Finished converting document uclc_directors-word.html in 0.02 sec.
# 2025-10-16 04:49:31,676 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:31,685 - INFO - Going to convert document batch...
# 2025-10-16 04:49:31,685 - INFO - Processing document Site_AcademicProgram.html
# 2025-10-16 04:49:31,699 - INFO - Finished converting document Site_AcademicProgram.html in 0.02 sec.
# 2025-10-16 04:49:31,797 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:31,812 - INFO - Going to convert document batch...
# 2025-10-16 04:49:31,813 - INFO - Processing document academics_uclc_photo.html
# 2025-10-16 04:49:31,828 - INFO - Finished converting document academics_uclc_photo.html in 0.03 sec.
#   📦 Processing batch 7 (100 chunks)...
#   ✅ Batch 7 added successfully
# 2025-10-16 04:49:35,854 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:35,871 - INFO - Going to convert document batch...
# 2025-10-16 04:49:35,872 - INFO - Processing document business_hecmontreal.html
# 2025-10-16 04:49:35,888 - INFO - Finished converting document business_hecmontreal.html in 0.04 sec.
# 2025-10-16 04:49:35,997 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:36,003 - INFO - Going to convert document batch...
# 2025-10-16 04:49:36,004 - INFO - Processing document give-usek_contact-us.html
# 2025-10-16 04:49:36,015 - INFO - Finished converting document give-usek_contact-us.html in 0.02 sec.
# 2025-10-16 04:49:36,027 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:36,037 - INFO - Going to convert document batch...
# 2025-10-16 04:49:36,039 - INFO - Processing document uclc_ongoing-courses.html
# 2025-10-16 04:49:36,057 - INFO - Finished converting document uclc_ongoing-courses.html in 0.03 sec.
# 2025-10-16 04:49:36,238 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:36,247 - INFO - Going to convert document batch...
# 2025-10-16 04:49:36,247 - INFO - Processing document university-catalogue.html
# 2025-10-16 04:49:36,263 - INFO - Finished converting document university-catalogue.html in 0.03 sec.
# 2025-10-16 04:49:36,349 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:36,359 - INFO - Going to convert document batch...
# 2025-10-16 04:49:36,360 - INFO - Processing document business_dealing-room.html
# 2025-10-16 04:49:36,374 - INFO - Finished converting document business_dealing-room.html in 0.03 sec.
# 2025-10-16 04:49:36,479 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:36,488 - INFO - Going to convert document batch...
# 2025-10-16 04:49:36,489 - INFO - Processing document doctoral-college_news.html
# 2025-10-16 04:49:36,505 - INFO - Finished converting document doctoral-college_news.html in 0.03 sec.
# 2025-10-16 04:49:36,608 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:36,619 - INFO - Going to convert document batch...
# 2025-10-16 04:49:36,619 - INFO - Processing document en_faculty-of-law_llm.html
# 2025-10-16 04:49:36,631 - INFO - Finished converting document en_faculty-of-law_llm.html in 0.03 sec.
#   📦 Processing batch 8 (100 chunks)...
#   ✅ Batch 8 added successfully
# 2025-10-16 04:49:40,755 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:40,769 - INFO - Going to convert document batch...
# 2025-10-16 04:49:40,770 - INFO - Processing document en_international_news.html
# 2025-10-16 04:49:40,782 - INFO - Finished converting document en_international_news.html in 0.03 sec.
# 2025-10-16 04:49:40,884 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:40,898 - INFO - Going to convert document batch...
# 2025-10-16 04:49:40,899 - INFO - Processing document fr_faculte-de-gestion.html
# 2025-10-16 04:49:40,911 - INFO - Finished converting document fr_faculte-de-gestion.html in 0.03 sec.
# 2025-10-16 04:49:40,989 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:40,997 - INFO - Going to convert document batch...
# 2025-10-16 04:49:40,997 - INFO - Processing document news_ai-workshop-2019.html
# 2025-10-16 04:49:41,010 - INFO - Finished converting document news_ai-workshop-2019.html in 0.02 sec.
# 2025-10-16 04:49:41,092 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:41,100 - INFO - Going to convert document batch...
# 2025-10-16 04:49:41,101 - INFO - Processing document business_accreditation.html
# 2025-10-16 04:49:41,113 - INFO - Finished converting document business_accreditation.html in 0.02 sec.
# 2025-10-16 04:49:41,207 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:41,215 - INFO - Going to convert document batch...
# 2025-10-16 04:49:41,216 - INFO - Processing document en_about-usek_rankings.html
# 2025-10-16 04:49:41,230 - INFO - Finished converting document en_about-usek_rankings.html in 0.02 sec.
# 2025-10-16 04:49:41,328 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:41,345 - INFO - Going to convert document batch...
# 2025-10-16 04:49:41,346 - INFO - Processing document en_contact_main-campus.html
# 2025-10-16 04:49:41,359 - INFO - Finished converting document en_contact_main-campus.html in 0.03 sec.
# 2025-10-16 04:49:41,488 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:41,500 - INFO - Going to convert document batch...
# 2025-10-16 04:49:41,501 - INFO - Processing document en_news-and-media_news.html
# 2025-10-16 04:49:41,517 - INFO - Finished converting document en_news-and-media_news.html in 0.03 sec.
#   📦 Processing batch 9 (100 chunks)...
#   ✅ Batch 9 added successfully
# 2025-10-16 04:49:45,507 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:45,525 - INFO - Going to convert document batch...
# 2025-10-16 04:49:45,526 - INFO - Processing document fr_a-propos_classement.html
# 2025-10-16 04:49:45,542 - INFO - Finished converting document fr_a-propos_classement.html in 0.04 sec.
# 2025-10-16 04:49:45,629 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:45,637 - INFO - Going to convert document batch...
# 2025-10-16 04:49:45,637 - INFO - Processing document fr_vie-academique_ltec.html
# 2025-10-16 04:49:45,649 - INFO - Finished converting document fr_vie-academique_ltec.html in 0.02 sec.
# 2025-10-16 04:49:45,732 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:45,743 - INFO - Going to convert document batch...
# 2025-10-16 04:49:45,744 - INFO - Processing document library_english_ask-us.html
# 2025-10-16 04:49:45,752 - INFO - deleted item in tree at stack: (9, 2, 2) => #/texts/38
# 2025-10-16 04:49:45,754 - INFO - deleted item in tree at stack: (9, 2, 2) => #/texts/38
# 2025-10-16 04:49:45,756 - INFO - deleted item in tree at stack: (9, 2, 2) => #/texts/38
# 2025-10-16 04:49:45,759 - INFO - deleted item in tree at stack: (9, 2, 2) => #/texts/50
# 2025-10-16 04:49:45,762 - INFO - deleted item in tree at stack: (9, 2, 2) => #/texts/50
# 2025-10-16 04:49:45,764 - INFO - deleted item in tree at stack: (9, 2, 2) => #/texts/50
# 2025-10-16 04:49:45,768 - INFO - Finished converting document library_english_ask-us.html in 0.04 sec.
# 2025-10-16 04:49:45,864 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:45,880 - INFO - Going to convert document batch...
# 2025-10-16 04:49:45,881 - INFO - Processing document students_student-voice.html
# 2025-10-16 04:49:45,906 - INFO - Finished converting document students_student-voice.html in 0.04 sec.
# 2025-10-16 04:49:46,046 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:46,056 - INFO - Going to convert document batch...
# 2025-10-16 04:49:46,057 - INFO - Processing document usek-diplomacy-academy.html
# 2025-10-16 04:49:46,071 - INFO - Finished converting document usek-diplomacy-academy.html in 0.04 sec.
# 2025-10-16 04:49:46,165 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:46,174 - INFO - Going to convert document batch...
# 2025-10-16 04:49:46,175 - INFO - Processing document a-propos_one-step-ahead.html
# 2025-10-16 04:49:46,186 - INFO - Finished converting document a-propos_one-step-ahead.html in 0.02 sec.
# 2025-10-16 04:49:46,263 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:46,271 - INFO - Going to convert document batch...
# 2025-10-16 04:49:46,271 - INFO - Processing document en_admission_contact-us.html
# 2025-10-16 04:49:46,285 - INFO - Finished converting document en_admission_contact-us.html in 0.02 sec.
# 2025-10-16 04:49:46,378 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:46,386 - INFO - Going to convert document batch...
# 2025-10-16 04:49:46,387 - INFO - Processing document fr_a-propos_gouvernance.html
# 2025-10-16 04:49:46,399 - INFO - Finished converting document fr_a-propos_gouvernance.html in 0.02 sec.
#   📦 Processing batch 10 (100 chunks)...
#   ✅ Batch 10 added successfully
# 2025-10-16 04:49:50,458 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:50,468 - INFO - Going to convert document batch...
# 2025-10-16 04:49:50,469 - INFO - Processing document fr_actualites-et-medias.html
# 2025-10-16 04:49:50,481 - INFO - Finished converting document fr_actualites-et-medias.html in 0.02 sec.
# 2025-10-16 04:49:50,568 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:50,576 - INFO - Going to convert document batch...
# 2025-10-16 04:49:50,577 - INFO - Processing document fr_etudiants_reglements.html
# 2025-10-16 04:49:50,592 - INFO - Finished converting document fr_etudiants_reglements.html in 0.03 sec.
# 2025-10-16 04:49:50,672 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:50,681 - INFO - Going to convert document batch...
# 2025-10-16 04:49:50,681 - INFO - Processing document fr_university-catalogue.html
# 2025-10-16 04:49:50,693 - INFO - Finished converting document fr_university-catalogue.html in 0.02 sec.
# 2025-10-16 04:49:50,764 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:50,774 - INFO - Going to convert document batch...
# 2025-10-16 04:49:50,774 - INFO - Processing document students_students-voice.html
# 2025-10-16 04:49:50,792 - INFO - Finished converting document students_students-voice.html in 0.03 sec.
# 2025-10-16 04:49:50,911 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:50,920 - INFO - Going to convert document batch...
# 2025-10-16 04:49:50,921 - INFO - Processing document en_about-usek_governance.html
# 2025-10-16 04:49:50,933 - INFO - Finished converting document en_about-usek_governance.html in 0.02 sec.
# 2025-10-16 04:49:51,033 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:51,045 - INFO - Going to convert document batch...
# 2025-10-16 04:49:51,046 - INFO - Processing document en_news-and-media_videos.html
# 2025-10-16 04:49:51,059 - INFO - Finished converting document en_news-and-media_videos.html in 0.03 sec.
#   📦 Processing batch 11 (100 chunks)...
#   ✅ Batch 11 added successfully
# 2025-10-16 04:49:55,125 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:55,137 - INFO - Going to convert document batch...
# 2025-10-16 04:49:55,138 - INFO - Processing document en_students_registration.html
# 2025-10-16 04:49:55,153 - INFO - Finished converting document en_students_registration.html in 0.03 sec.
# 2025-10-16 04:49:55,240 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:55,250 - INFO - Going to convert document batch...
# 2025-10-16 04:49:55,250 - INFO - Processing document faculty-of-law_colloquim.html
# 2025-10-16 04:49:55,264 - INFO - Finished converting document faculty-of-law_colloquim.html in 0.02 sec.
# 2025-10-16 04:49:55,374 - INFO - detected formats: [<InputFormat.HTML: 'html'>]
# 2025-10-16 04:49:55,392 - INFO - Going to convert document batch...
# 2025-10-16 04:49:55,392 - INFO - Processing document fr_a-propos_usek-en-bref.html
# 2025-10-16 04:49:55,407 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/133
# 2025-10-16 04:49:55,409 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/133
# 2025-10-16 04:49:55,411 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/133
# 2025-10-16 04:49:55,414 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/135
# 2025-10-16 04:49:55,418 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/138
# 2025-10-16 04:49:55,421 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/138
# 2025-10-16 04:49:55,424 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/138
# 2025-10-16 04:49:55,426 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/140
# 2025-10-16 04:49:55,429 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/142
# 2025-10-16 04:49:55,432 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/145
# 2025-10-16 04:49:55,434 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/145
# 2025-10-16 04:49:55,437 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/145
# 2025-10-16 04:49:55,440 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/145
# 2025-10-16 04:49:55,443 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/145
# 2025-10-16 04:49:55,445 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/145
# 2025-10-16 04:49:55,448 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/145
# 2025-10-16 04:49:55,451 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/147
# 2025-10-16 04:49:55,454 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/149
# 2025-10-16 04:49:55,457 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/152
# 2025-10-16 04:49:55,462 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/154
# 2025-10-16 04:49:55,467 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/157
# 2025-10-16 04:49:55,470 - INFO - deleted item in tree at stack: (6, 1, 29) => #/texts/160
# 2025-10-16 04:49:55,474 - INFO - deleted item in tree at stack: (6, 1, 29, 5) => #/texts/170
# 2025-10-16 04:49:55,477 - INFO - deleted item in tree at stack: (6, 1, 29, 5) => #/texts/170
# 2025-10-16 04:49:55,481 - INFO - deleted item in tree at stack: (6, 1, 29, 5) => #/texts/170
# 2025-10-16 04:49:55,484 - INFO - deleted item in tree at stack: (6, 1, 29, 5) => #/texts/170
# 2025-10-16 04:49:55,487 - INFO - deleted item in tree at stack: (6, 1, 29, 5) => #/texts/170
# 2025-10-16 04:49:55,490 - INFO - deleted item in tree at stack: (6, 1, 29, 5) => #/texts/170
# 2025-10-16 04:49:55,493 - INFO - deleted item in tree at stack: (6, 1, 29, 5) => #/texts/170
# 2025-10-16 04:49:55,497 - INFO - deleted item in tree at stack: (6, 1, 29, 5) => #/texts/170
# 2025-10-16 04:49:55,507 - INFO - deleted item in tree at stack: (6, 1, 29, 5) => #/texts/170
# 2025-10-16 04:49:55,510 - INFO - deleted item in tree at stack: (6, 1, 29, 5) => #/texts/170
# ...
# -> 1387         self._handle_batch_operation_exception(
#    1388             e, batch_insert_list, i, total_count, "insert"
#    1389         )
#    1390 return pks
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:1428, in Milvus._handle_batch_operation_exception(self, e, batch_list, batch_index, total_count, operation_name)
#    1421 logger.error(
#    1422     "Failed to %s batch starting at entity: %s/%s. " "First entity data: %s",
#    1423     operation_name,
#    (...)   1426     log_entity,
#    1427 )
# -> 1428 raise e
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:1379, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1378 timeout = self.timeout or timeout
# -> 1379 res = self.client.insert(
#    1380     self.collection_name,
#    1381     batch_insert_list,
#    1382     timeout=timeout,
#    1383     **kwargs,
#    1384 )
#    1385 pks.extend(res["ids"])
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:233, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     232 except Exception as ex:
# --> 233     raise ex from ex
#     234 return OmitZeroDict(
#     235     {
#     236         "insert_count": res.insert_count,
#    (...)    239     }
#     240 )
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:229, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     228 try:
# --> 229     res = conn.insert_rows(
#     230         collection_name, data, partition_name=partition_name, timeout=timeout
#     231     )
#     232 except Exception as ex:
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:141, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     140     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 141     raise e from e
#     142 except grpc.FutureTimeoutError as e:
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:137, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     136     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 137     return func(*args, **kwargs)
#     138 except MilvusException as e:
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:173, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     172     self.set_onetime_loglevel(level)
# --> 173 return func(self, *args, **kwargs)
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:92, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      91 if timeout(start_time):
# ---> 92     raise MilvusException(e.code, f"{to_msg}, message={e.details()}") from e
#      94 if counter > 3:
#
# MilvusException: <MilvusException: (code=<bound method _InactiveRpcError.code of <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B::1%5D:19530: Failed to connect to remote host: connect: Connection refused (111)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B::1%5D:19530: Failed to connect to remote host: connect: Connection refused (111)"}"
# >>, message=[insert_rows] Retry run out of 75 retry times, message=failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B::1%5D:19530: Failed to connect to remote host: connect: Connection refused (111))>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[59], line 1
# ----> 1 store = ingest_pipeline(directory)
#
# Cell In[58], line 101, in ingest_pipeline(directory_path, recursive, file_extensions, batch_size)
#     100 _print_info("  📦", f"Processing batch {batch_count} ({len(batch)} chunks)...")
# --> 101 vector_store.add_documents(batch)
#     102 _print_success("  ✅", f"Batch {batch_count} added successfully")
#
# Cell In[57], line 68, in VectorStore.add_documents(self, documents)
#      66     raise ValueError("Documents list cannot be empty")
# ---> 68 return self.vectorstore.add_documents(documents)
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:2115, in Milvus.add_documents(self, documents, **kwargs)
#    2114 metadatas = [doc.metadata for doc in documents]
# -> 2115 return self.add_texts(texts, metadatas, **kwargs)
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:1278, in Milvus.add_texts(self, texts, metadatas, timeout, batch_size, ids, **kwargs)
#    1276     transposed_embeddings = embeddings[0] if len(embeddings) > 0 else []
# -> 1278 return self.add_embeddings(
#    1279     texts=texts,
#    1280     embeddings=transposed_embeddings,
#    1281     metadatas=metadatas,
#    1282     timeout=timeout,
#    1283     batch_size=batch_size,
#    1284     ids=ids,
#    1285     **kwargs,
#    1286 )
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:1387, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1386     except MilvusException as e:
# -> 1387         self._handle_batch_operation_exception(
#    1388             e, batch_insert_list, i, total_count, "insert"
#    1389         )
#    1390 return pks
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:1428, in Milvus._handle_batch_operation_exception(self, e, batch_list, batch_index, total_count, operation_name)
#    1421 logger.error(
#    1422     "Failed to %s batch starting at entity: %s/%s. " "First entity data: %s",
#    1423     operation_name,
#    (...)   1426     log_entity,
#    1427 )
# -> 1428 raise e
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:1379, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1378 timeout = self.timeout or timeout
# -> 1379 res = self.client.insert(
#    1380     self.collection_name,
#    1381     batch_insert_list,
#    1382     timeout=timeout,
#    1383     **kwargs,
#    1384 )
#    1385 pks.extend(res["ids"])
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:233, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     232 except Exception as ex:
# --> 233     raise ex from ex
#     234 return OmitZeroDict(
#     235     {
#     236         "insert_count": res.insert_count,
#    (...)    239     }
#     240 )
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:229, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     228 try:
# --> 229     res = conn.insert_rows(
#     230         collection_name, data, partition_name=partition_name, timeout=timeout
#     231     )
#     232 except Exception as ex:
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:141, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     140     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 141     raise e from e
#     142 except grpc.FutureTimeoutError as e:
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:137, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     136     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 137     return func(*args, **kwargs)
#     138 except MilvusException as e:
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:173, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     172     self.set_onetime_loglevel(level)
# --> 173 return func(self, *args, **kwargs)
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:92, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      91 if timeout(start_time):
# ---> 92     raise MilvusException(e.code, f"{to_msg}, message={e.details()}") from e
#      94 if counter > 3:
#
# MilvusException: <MilvusException: (code=<bound method _InactiveRpcError.code of <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B::1%5D:19530: Failed to connect to remote host: connect: Connection refused (111)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B::1%5D:19530: Failed to connect to remote host: connect: Connection refused (111)"}"
# >>, message=[insert_rows] Retry run out of 75 retry times, message=failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B::1%5D:19530: Failed to connect to remote host: connect: Connection refused (111))>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 store = ingest_pipeline(directory)
#
# Cell In[58], line 101, in ingest_pipeline(directory_path, recursive, file_extensions, batch_size)
#      99 batch_count += 1
#     100 _print_info("  📦", f"Processing batch {batch_count} ({len(batch)} chunks)...")
# --> 101 vector_store.add_documents(batch)
#     102 _print_success("  ✅", f"Batch {batch_count} added successfully")
#     103 batch = []
#
# Cell In[57], line 68, in VectorStore.add_documents(self, documents)
#      65 if not documents:
#      66     raise ValueError("Documents list cannot be empty")
# ---> 68 return self.vectorstore.add_documents(documents)
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:2115, in Milvus.add_documents(self, documents, **kwargs)
#    2113 texts = [doc.page_content for doc in documents]
#    2114 metadatas = [doc.metadata for doc in documents]
# -> 2115 return self.add_texts(texts, metadatas, **kwargs)
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:1278, in Milvus.add_texts(self, texts, metadatas, timeout, batch_size, ids, **kwargs)
#    1270 else:
#    1271     # transposed_embeddings = [
#    1272     #     f1(a),
#    1273     #     f1(b),
#    1274     #     f1(c)
#    1275     # ]
#    1276     transposed_embeddings = embeddings[0] if len(embeddings) > 0 else []
# -> 1278 return self.add_embeddings(
#    1279     texts=texts,
#    1280     embeddings=transposed_embeddings,
#    1281     metadatas=metadatas,
#    1282     timeout=timeout,
#    1283     batch_size=batch_size,
#    1284     ids=ids,
#    1285     **kwargs,
#    1286 )
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:1387, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1385         pks.extend(res["ids"])
#    1386     except MilvusException as e:
# -> 1387         self._handle_batch_operation_exception(
#    1388             e, batch_insert_list, i, total_count, "insert"
#    1389         )
#    1390 return pks
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:1428, in Milvus._handle_batch_operation_exception(self, e, batch_list, batch_index, total_count, operation_name)
#    1420         log_entity[k] = v
#    1421 logger.error(
#    1422     "Failed to %s batch starting at entity: %s/%s. " "First entity data: %s",
#    1423     operation_name,
#    (...)   1426     log_entity,
#    1427 )
# -> 1428 raise e
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/langchain_milvus/vectorstores/milvus.py:1379, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1377 try:
#    1378     timeout = self.timeout or timeout
# -> 1379     res = self.client.insert(
#    1380         self.collection_name,
#    1381         batch_insert_list,
#    1382         timeout=timeout,
#    1383         **kwargs,
#    1384     )
#    1385     pks.extend(res["ids"])
#    1386 except MilvusException as e:
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:233, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     229     res = conn.insert_rows(
#     230         collection_name, data, partition_name=partition_name, timeout=timeout
#     231     )
#     232 except Exception as ex:
# --> 233     raise ex from ex
#     234 return OmitZeroDict(
#     235     {
#     236         "insert_count": res.insert_count,
#    (...)    239     }
#     240 )
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:229, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     227 # Insert into the collection.
#     228 try:
# --> 229     res = conn.insert_rows(
#     230         collection_name, data, partition_name=partition_name, timeout=timeout
#     231     )
#     232 except Exception as ex:
#     233     raise ex from ex
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:141, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     139     record_dict["RPC error"] = str(datetime.datetime.now())
#     140     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 141     raise e from e
#     142 except grpc.FutureTimeoutError as e:
#     143     record_dict["gRPC timeout"] = str(datetime.datetime.now())
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:137, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     135 try:
#     136     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 137     return func(*args, **kwargs)
#     138 except MilvusException as e:
#     139     record_dict["RPC error"] = str(datetime.datetime.now())
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:173, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     171 if level:
#     172     self.set_onetime_loglevel(level)
# --> 173 return func(self, *args, **kwargs)
#
# File ~/Desktop/github/having_fun/.venv/lib/python3.13/site-packages/pymilvus/decorators.py:92, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      90     raise e from e
#      91 if timeout(start_time):
# ---> 92     raise MilvusException(e.code, f"{to_msg}, message={e.details()}") from e
#      94 if counter > 3:
#      95     retry_msg = (
#      96         f"[{func.__name__}] retry:{counter}, cost: {back_off:.2f}s, "
#      97         f"reason: <{e.__class__.__name__}: {e.code()}, {e.details()}>"
#      98     )
#
# MilvusException: <MilvusException: (code=<bound method _InactiveRpcError.code of <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B::1%5D:19530: Failed to connect to remote host: connect: Connection refused (111)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B::1%5D:19530: Failed to connect to remote host: connect: Connection refused (111)"}"
# >>, message=[insert_rows] Retry run out of 75 retry times, message=failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B::1%5D:19530: Failed to connect to remote host: connect: Connection refused (111))>
